# %%
import pandas as pd
df = pd.read_csv('ZILL-Z77006_3B.csv')
print(df.head())
# Out:
#          Date     Value
# 0  2016-09-30  465600.0
# 1  2016-08-31  470100.0
# 2  2016-07-31  474500.0
# 3  2016-06-30  480900.0
# 4  2016-05-31  491400.0

# %%
import pandas as pd
df = pd.read_csv('newcsv2.csv', names = ['Date','House_Price'], index_col=0)
print(df.head())
# Out:
#            House_Price
# Date
# Date             Value
# 2016-11-30    630400.0
# 2016-10-31    633800.0
# 2016-09-30    622900.0
# 2016-08-31    631300.0

# %%
import pandas as pd
df = pd.read_csv('newcsv2.csv', names = ['Date','House_Price'])
print(df.head())
df.rename(columns={'House_Price':'Prices'}, inplace=True)
print(df.head())
# Out:
#          Date House_Price
# 0        Date       Value
# 1  2016-11-30    630400.0
# 2  2016-10-31    633800.0
# 3  2016-09-30    622900.0
# 4  2016-08-31    631300.0
#          Date    Prices
# 0        Date     Value
# 1  2016-11-30  630400.0
# 2  2016-10-31  633800.0
# 3  2016-09-30  622900.0
# 4  2016-08-31  631300.0

# %%
import pandas as pd
df = pd.read_csv('newcsv2.csv', names = ['Date','House_Price'])
a = df.to_html('example.html')
print(a)
# Out:
# None
